# %%
import json
import requests
link="https://economia.awesomeapi.com.br/last/USD-BRL,EUR-BRL,BTC-BRL"
o=requests.get(link)
d=o.json()
print(d)
# Out:
# {'USDBRL': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '5.1353', 'low': '5.095', 'varBid': '-0.0135', 'pctChange': '-0.264106', 'bid': '5.098', 'ask': '5.099', 'timestamp': '1790112028', 'create_date': '2026-09-22 18:20:28'}, 'EURBRL': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '5.8852', 'low': '5.8333', 'varBid': '-0.0214', 'pctChange': '-0.365257', 'bid': '5.8375', 'ask': '5.8395', 'timestamp': '1790111952', 'create_date': '2026-09-22 18:19:12'}, 'BTCBRL': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '445231', 'low': '435929', 'varBid': '-2844', 'pctChange': '-0.641', 'bid': '440494', 'ask': '440534', 'timestamp': '1790112029', 'create_date': '2026-09-22 18:20:29'}}

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<p>Hello, World!</p>"

@app.route("/enzoquistão")
def novomundo():
    return "<p>VIVA O ENZOQUISTÃO</p>"
app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [22/Sep/2026 19:39:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2026 19:39:22] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [22/Sep/2026 19:40:10] "GET /enzoquistão HTTP/1.1" 200 -
